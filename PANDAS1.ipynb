# %% [markdown]
# <a href="https://colab.research.google.com/github/singhShreyaCoder/Python-libraries/blob/main/PANDAS1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import pandas as pd
import numpy as np

# %%
#machine learning process
#1.problem defination
#2.data collection => primary and secondary
#3.data preprocessing => data cleaning,integration,transformation
#4.EDA(exploaratory data analysis)
#5.feature engineering
#6.model selection
#7.train test split=> (80-20),(70,30)
#8.model training
#9.model testing and evaluation
#10.deployment

#data=>qualitative(nominal,ordinal),quantitative(interval,ratio)

# %%
s=pd.Series()
print("pandas series:",s)

#create a series
data=np.array(["a","b","c","d","e"])
s=pd.Series([data])
print("Pandas series:",s )

print(data[3])
# Out:
# pandas series: Series([], dtype: object)
# Pandas series: 0    [a, b, c, d, e]
# dtype: object
# d

# %%
import pandas as pd

calories={"day1":420,"day2":300,"day3":390}
ser=pd.Series(calories)
#print(ser)

myvar=pd.Series(calories,index=["day1","day2"])
print(myvar)
# Out:
# day1    420
# day2    300
# dtype: int64

# %%
#dataframe
import pandas as pd
df=pd.DataFrame()
#print(df)

#creating a datframe from list
lst=['geeks','for','geeks','is','portal','for','geeks']
df=pd.DataFrame(lst)
#print(df)

#Create dataframe from key value pair
# Out:
#         0
# 0   geeks
# 1     for
# 2   geeks
# 3      is
# 4  portal
# 5     for
# 6   geeks

# %%
#Create dataframe from key value pair
import pandas as pd
import numpy as np

data= {
    "calories":[420,380,390],
    "duration":[50,40,45]
}
df=pd.DataFrame(data)
print(df)

# %%
import pandas as pd
import numpy as np

data={
    "name":['A','B','C','D','None','E'],
    "age":[21,19,20,np.nan,18,19],
    "course":["B.tech","BCA","MCA","None","B.tech","BCA"],
    "marks":[75,60,74,np.nan,65,67]
}

df=pd.DataFrame(data)
print(df.shape)
print(df.info())
print(df.head(2))
print(df.tail(4))
print(df.describe())
# Out:
# (6, 4)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    6 non-null      object
#  1   age     5 non-null      float64
#  2   course  6 non-null      object
#  3   marks   5 non-null      float64
# dtypes: float64(2), object(2)
# memory usage: 324.0+ bytes
# None
#   name   age  course  marks
# 0    A  21.0  B.tech   75.0
# 1    B  19.0     BCA   60.0
#    name   age  course  marks
# 2     C  20.0     MCA   74.0
# 3     D   NaN    None    NaN
# 4  None  18.0  B.tech   65.0
# 5     E  19.0     BCA   67.0
#              age      marks
# count   5.000000   5.000000
# mean   19.400000  68.200000
# std     1.140175   6.300794
# min    18.000000  60.000000
# 25%    19.000000  65.000000
# 50%    19.000000  67.000000
# 75%    20.000000  74.000000
# max    21.000000  75.000000
